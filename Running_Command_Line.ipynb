# %%
! mpiexec -n 4 python MPI_Particles.py
# Out:
# This is process 3 and the initial posistions I have are [[0.53333333 0.53333333]
#  [0.62222222 0.53333333]
#  [0.71111111 0.53333333]
#  [0.8        0.53333333]
#  [0.53333333 0.62222222]
#  [0.62222222 0.62222222]
#  [0.71111111 0.62222222]
#  [0.8        0.62222222]
#  [0.53333333 0.71111111]
#  [0.62222222 0.71111111]
#  [0.71111111 0.71111111]
#  [0.8        0.71111111]
#  [0.53333333 0.8       ]
#  [0.62222222 0.8       ]
#  [0.71111111 0.8       ]
#  [0.8        0.8       ]].
# This is process 1 and the initial posistions I have are [[0.53333333 0.08888889]
#  [0.62222222 0.08888889]
#  [0.71111111 0.08888889]
#  [0.8        0.08888889]
#  [0.53333333 0.17777778]
#  [0.62222222 0.17777778]
#  [0.71111111 0.17777778]
#  [0.8        0.17777778]
#  [0.53333333 0.26666667]
#  [0.62222222 0.26666667]
#  [0.71111111 0.26666667]
#  [0.8        0.26666667]
#  [0.53333333 0.35555556]
#  [0.62222222 0.35555556]
#  [0.71111111 0.35555556]
#  [0.8        0.35555556]
# ...
